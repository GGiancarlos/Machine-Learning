# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4)

# %%
data

# %%
plt.scatter(data[0][:,0], data[0][:,1])

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=4)

# %%
model.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
model.cluster_centers_
# Out:
# array([[ 9.30350366, -4.6639718 ],
#        [-3.9637628 ,  8.72484741],
#        [ 5.3714492 , -3.84430526],
#        [ 9.29174994,  1.06110342]])

# %%
model.labels_
# Out:
# array([2, 0, 3, 0, 2, 2, 0, 3, 3, 2, 2, 0, 3, 2, 0, 2, 2, 1, 2, 2, 3, 1,
#        0, 3, 2, 3, 0, 3, 0, 3, 3, 0, 3, 2, 2, 2, 2, 1, 1, 3, 1, 2, 3, 0,
#        3, 2, 1, 2, 0, 0, 3, 3, 0, 2, 0, 2, 1, 0, 1, 0, 2, 0, 1, 2, 3, 3,
#        3, 3, 0, 3, 3, 1, 1, 0, 1, 0, 0, 3, 1, 1, 3, 2, 0, 3, 1, 2, 2, 1,
#        3, 2, 0, 1, 2, 1, 2, 2, 2, 3, 0, 1, 0, 1, 1, 2, 3, 0, 0, 0, 3, 0,
#        0, 1, 2, 3, 0, 0, 0, 1, 3, 2, 3, 2, 2, 0, 1, 1, 3, 3, 3, 1, 2, 0,
#        0, 2, 1, 0, 3, 1, 3, 0, 1, 2, 1, 2, 1, 1, 3, 1, 3, 1, 1, 0, 2, 0,
#        1, 1, 3, 2, 0, 0, 0, 1, 1, 3, 2, 0, 2, 1, 1, 0, 3, 3, 0, 3, 3, 1,
#        0, 3, 1, 1, 0, 1, 2, 3, 1, 2, 2, 1, 0, 1, 1, 2, 3, 2, 2, 3, 0, 1,
#        2, 3])

# %%
plt.scatter(data[0][:,0], data[0][:,1])
plt.plot(model.cluster_centers_[:,0],model.cluster_centers_[:,1], 'ro')

# %%
fig, (ax0, ax1) = plt.subplots(1,2, figsize=(12,4))

ax0.scatter(data[0][:,0], data[0][:,1], c=model.labels_)
ax0.set_title('Implemented K-Means')

ax1.scatter(data[0][:,0], data[0][:,1], c=data[1])
ax1.set_title('Original Data')
# Out:
# Text(0.5, 1.0, 'Original Data')
